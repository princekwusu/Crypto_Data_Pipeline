# %%
import pandas as pd

# %%
btcusdt = pd.read_csv('BTCUSDT_1h.csv')

# %%
btcusdt
# Out:
#           open_time      open      high       low     close      volume  \
# 0     1704067200000  42283.58  42554.57  42261.02  42475.23  1271.68108
# 1     1704070800000  42475.23  42775.00  42431.65  42613.56  1196.37856
# 2     1704074400000  42613.57  42638.41  42500.00  42581.10   685.21980
# 3     1704078000000  42581.09  42586.64  42230.08  42330.49   794.80391
# 4     1704081600000  42330.50  42399.99  42209.46  42399.99   715.41760
# ...             ...       ...       ...       ...       ...         ...
# 3274  1715853600000  66364.69  66364.69  66100.00  66169.99   747.09629
# 3275  1715857200000  66170.00  66585.70  66000.00  66503.80   933.73337
# 3276  1715860800000  66503.81  66752.01  65904.76  66011.01  2444.27960
# 3277  1715864400000  66011.01  66367.92  65759.99  66328.05  1698.98043
# 3278  1715868000000  66328.06  66393.29  65976.01  66054.88   542.82448
#
#          close_time  quote_asset_volume  num_trades  taker_base_vol  \
# ...

# %%
btcusdt.drop(columns=['ignore', 'order_book'], inplace=True)
